# %%
import numpy as np
from sklearn.metrics import mean_squared_error
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
from sklearn.linear_model import LinearRegression, Lasso, LassoCV, Ridge, RidgeCV
from sklearn.tree import DecisionTreeClassifier, export_graphviz
# %matplotlib inline
d = pd.read_csv('student_mat.csv', sep=';')
d['avg_g'] = (d['G1']+d['G2']+d['G3'])/3

# %%
categorical_columns = [c for c in d.columns if d[c].dtype.name == 'object']
numerical_columns   = [c for c in d.columns if d[c].dtype.name != 'object']
d_describe = d.describe(include=[object])

# %%
binary_columns    = [c for c in categorical_columns if d_describe[c]['unique'] == 2]
nonbinary_columns = [c for c in categorical_columns if d_describe[c]['unique'] > 2]

# %%
for c in binary_columns[0:]:
    top = d_describe[c]['top']
    top_items = d[c] == top
    d.loc[top_items, c] = 0
    d.loc[np.logical_not(top_items), c] = 1

# %%
d_nonbinary = pd.get_dummies(d[nonbinary_columns])

# %%
d_numerical = d[numerical_columns]
d_numerical = (d_numerical - d_numerical.mean()) / d_numerical.std()

# %%
d = pd.concat((d_numerical, d[binary_columns], d_nonbinary), axis=1)
d = pd.DataFrame(d, dtype=float)

# %%
X = d.drop(['avg_g', 'G1','G2','G3'],axis = 1)
y = d['avg_g']
feature_names = X.columns
feature_names
# Out:
# Index(['age', 'Medu', 'Fedu', 'traveltime', 'studytime', 'failures',
#        'schoolsup', 'famsup', 'paid', 'activities', 'nursery', 'higher',
#        'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc', 'Walc',
#        'health', 'absences', 'sex', 'address', 'famsize', 'Pstatus',
#        'Mjob_at_home', 'Mjob_health', 'Mjob_other', 'Mjob_services',
#        'Mjob_teacher', 'Fjob_at_home', 'Fjob_health', 'Fjob_other',
#        'Fjob_services', 'Fjob_teacher', 'reason_course', 'reason_home',
#        'reason_other', 'reason_reputation', 'guardian_father',
#        'guardian_mother', 'guardian_other'],
#       dtype='object')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 11)

# %%
lin = LinearRegression(normalize=True)
lin.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=True)

# %%
y_lin_pred = lin.predict(X_test)

# %%
def rmse(y, p):
    return np.sqrt(mean_squared_error(y, p))

# %%
def beatiful_coef(coefs, feature_names=d.columns):
    return pd.DataFrame(coefs, index=feature_names,
                       columns=['coef']).sort_values('coef',
                                                  ascending=False)

# %%
rmse(y_test, y_lin_pred)
# Out:
# 0.89871158910308002

# %%
beatiful_coef(lin.coef_,feature_names=X_train.columns)
# Out:
#                            coef
# reason_other       2.116213e+12
# reason_reputation  2.116213e+12
# reason_home        2.116213e+12
# reason_course      2.116213e+12
# Mjob_health        8.562560e+11
# Mjob_services      8.562560e+11
# Mjob_at_home       8.562560e+11
# Mjob_other         8.562560e+11
# Mjob_teacher       8.562560e+11
# sex                3.102730e-01
# famsize            1.558906e-01
# studytime          1.188325e-01
# higher             8.739094e-02
# freetime           7.933780e-02
# Medu               6.328185e-02
# Walc               5.446171e-02
# Pstatus            5.016957e-02
# paid               4.796797e-02
# Fedu               2.811377e-02
# internet           1.929969e-02
# famrel             1.829051e-02
# absences           9.021298e-03
# activities         8.665782e-03
# traveltime        -4.624126e-03
# nursery           -7.750076e-03
# age               -6.485474e-02
# romantic          -7.097202e-02
# health            -7.427539e-02
# address           -7.748759e-02
# Dalc              -1.251632e-01
# famsup            -1.362098e-01
# schoolsup         -1.695782e-01
# goout             -1.850898e-01
# failures          -2.309718e-01
# Fjob_teacher      -6.999747e+10
# Fjob_at_home      -6.999747e+10
# Fjob_health       -6.999747e+10
# Fjob_services     -6.999747e+10
# Fjob_other        -6.999747e+10
# guardian_other    -9.339869e+12
# guardian_mother   -9.339869e+12
# guardian_father   -9.339869e+12

# %%
ridge = Ridge(random_state=17, normalize=True)
ridge.fit(X_train, y_train)
# Out:
# Ridge(alpha=1.0, copy_X=True, fit_intercept=True, max_iter=None,
#    normalize=True, random_state=17, solver='auto', tol=0.001)

# %%
beatiful_coef(ridge.coef_,feature_names=X_train.columns)
# Out:
#                        coef
# Fjob_teacher       0.236049
# Fjob_at_home       0.229060
# Mjob_health        0.146997
# sex                0.136118
# Mjob_services      0.109901
# reason_other       0.091353
# famsize            0.078008
# Pstatus            0.063077
# higher             0.061414
# reason_reputation  0.051885
# Medu               0.046895
# studytime          0.045268
# Fedu               0.030011
# paid               0.025185
# freetime           0.024416
# Fjob_health        0.020504
# internet           0.019779
# activities         0.015675
# famrel             0.015432
# guardian_mother    0.009710
# nursery            0.000717
# guardian_father   -0.006994
# absences          -0.011725
# guardian_other    -0.012568
# reason_home       -0.017285
# Fjob_services     -0.018978
# traveltime        -0.020755
# Walc              -0.023153
# health            -0.027131
# age               -0.032312
# Dalc              -0.036067
# romantic          -0.040317
# Mjob_teacher      -0.042344
# Mjob_at_home      -0.047511
# reason_course     -0.057715
# address           -0.058074
# famsup            -0.060760
# goout             -0.076454
# schoolsup         -0.082200
# Mjob_other        -0.085335
# Fjob_other        -0.088795
# failures          -0.121633

# %%
ridge_valid_pred = ridge.predict(X_test)

# %%
rmse(y_test, ridge_valid_pred)
# Out:
# 0.89187199257737915

# %%
alphas = np.logspace(-4, 4, 100)
ridge_cv = RidgeCV(alphas=alphas,cv=5, normalize=True).fit(X_train, y_train)
ridge_cv.alpha_
# Out:
# 0.52140082879996896

# %%
best_ridge_test_pred = ridge_cv.predict(X_test)
rmse(y_test, best_ridge_test_pred)
# Out:
# 0.88588524868828489

# %%
lasso = LassoCV(alphas=alphas, cv=5, normalize=True).fit(X_train, y_train)
lasso.alpha_
# Out:
# 0.0016297508346206436

# %%
best_lasso_test_pred = lasso.predict(X_test)
rmse(y_test, best_lasso_test_pred)
# Out:
# 0.871057777621561

# %%
beatiful_coef(lasso.coef_,feature_names=X_train.columns)
# Out:
#                        coef
# Fjob_teacher       0.407595
# Mjob_health        0.330361
# Fjob_at_home       0.314568
# Mjob_services      0.263223
# sex                0.219016
# reason_other       0.088672
# famsize            0.081574
# higher             0.076873
# studytime          0.075803
# Medu               0.051287
# reason_reputation  0.046564
# freetime           0.036806
# paid               0.013045
# internet           0.003547
# Pstatus            0.002371
# Fedu               0.000377
# reason_home       -0.000000
# guardian_father   -0.000000
# Fjob_services     -0.000000
# Fjob_health        0.000000
# Mjob_teacher      -0.000000
# guardian_mother    0.000000
# Mjob_at_home       0.000000
# guardian_other     0.000000
# nursery            0.000000
# Walc              -0.000000
# activities         0.000000
# famrel             0.000000
# absences          -0.000000
# traveltime        -0.000104
# age               -0.025820
# Mjob_other        -0.036889
# health            -0.037825
# reason_course     -0.037855
# romantic          -0.039878
# address           -0.044807
# Dalc              -0.052783
# Fjob_other        -0.091290
# famsup            -0.093446
# goout             -0.126987
# schoolsup         -0.129052
# failures          -0.230188

# %%
beatiful_coef(ridge_cv.coef_,feature_names=X_train.columns)
# Out:
#                        coef
# Fjob_teacher       0.314814
# Fjob_at_home       0.284340
# Mjob_health        0.192033
# sex                0.185471
# Mjob_services      0.142105
# reason_other       0.123186
# famsize            0.101955
# higher             0.072885
# Pstatus            0.070186
# studytime          0.062040
# reason_reputation  0.058745
# Medu               0.051161
# freetime           0.036286
# paid               0.031568
# Fedu               0.030783
# Fjob_health        0.023779
# internet           0.022122
# famrel             0.017439
# activities         0.015578
# guardian_other     0.015170
# guardian_mother    0.008657
# nursery           -0.002998
# absences          -0.009406
# guardian_father   -0.015439
# Walc              -0.017490
# traveltime        -0.018428
# reason_home       -0.024830
# Fjob_services     -0.032499
# health            -0.037830
# age               -0.039281
# Mjob_at_home      -0.045473
# Dalc              -0.050249
# romantic          -0.050553
# address           -0.065343
# reason_course     -0.066815
# famsup            -0.083950
# Mjob_teacher      -0.088842
# Mjob_other        -0.101175
# goout             -0.103053
# Fjob_other        -0.108841
# schoolsup         -0.109067
# failures          -0.154414

# %%
from sklearn.ensemble import RandomForestRegressor
forest = RandomForestRegressor(n_estimators=100, random_state=17)
forest.fit(X_train, y_train)
forest_test_pred = forest.predict(X_test)

# %%
rmse(y_test, forest_test_pred)
# Out:
# 0.83743555911559397

# %%
beatiful_coef(forest.feature_importances_,feature_names=X_train.columns)
# Out:
#                        coef
# failures           0.119483
# absences           0.110960
# freetime           0.058807
# age                0.043564
# goout              0.042472
# Walc               0.037686
# health             0.037620
# schoolsup          0.036184
# studytime          0.033960
# Fedu               0.033782
# Medu               0.032531
# Mjob_services      0.030454
# famrel             0.026898
# sex                0.023545
# Fjob_other         0.022542
# Fjob_teacher       0.021085
# traveltime         0.020270
# famsup             0.018392
# famsize            0.016442
# higher             0.015838
# Mjob_at_home       0.015770
# Mjob_other         0.013610
# romantic           0.013593
# reason_course      0.013537
# Dalc               0.013361
# guardian_other     0.013126
# reason_home        0.012297
# Mjob_health        0.012048
# reason_reputation  0.012001
# nursery            0.011741
# activities         0.010649
# paid               0.010125
# reason_other       0.009175
# internet           0.008160
# Mjob_teacher       0.007757
# address            0.007444
# Pstatus            0.006511
# Fjob_services      0.006105
# guardian_mother    0.006088
# guardian_father    0.006053
# Fjob_at_home       0.005999
# Fjob_health        0.002336
